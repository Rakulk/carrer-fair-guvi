# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('IMDB_movies.csv')

# %%
pd.set_option('display.max_columns', 500)

# %% [markdown]
# # Data preprocessing

# %%
data
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
data.tail()
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 5038  Color       Scott Smith                     1.0      87.0
# 5039  Color               NaN                    43.0      43.0
# 5040  Color  Benjamin Roberds                    13.0      76.0
# 5041  Color       Daniel Hsia                    14.0     100.0
# 5042  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  \
# 5038                   637.0      NaN                  Comedy|Drama
# ...

# %%
data.shape
# Out:
# (5043, 28)

# %%
print("total_columns :",data.shape[1])
print("total_rows :",data.shape[0])
# Out:
# total_columns : 28
# total_rows : 5043

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
data.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          20
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
percent_missing = data.isnull().sum() * 100 / len(data)
missing_values = pd.DataFrame({'percent_missing': percent_missing})
missing_values.sort_values(by ='percent_missing' , ascending=False)
# Out:
#                            percent_missing
# gross                            17.529248
# budget                            9.756098
# aspect_ratio                      6.523895
# content_rating                    6.008328
# plot_keywords                     3.033908
# title_year                        2.141582
# director_name                     2.062265
# director_facebook_likes           2.062265
# num_critic_for_reviews            0.991473
# actor_3_name                      0.456078
# actor_3_facebook_likes            0.456078
# num_user_for_reviews              0.396589
# color                             0.376760
# duration                          0.297442
# facenumber_in_poster              0.257783
# actor_2_name                      0.257783
# actor_2_facebook_likes            0.257783
# language                          0.237954
# actor_1_name                      0.138806
# actor_1_facebook_likes            0.138806
# country                           0.099147
# ...

# %%
data.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews          object
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %% [markdown]
# Imputation

# %%
data['color'].value_counts()
# Out:
# Color               4815
#  Black and White     209
# Name: color, dtype: int64

# %%
data['color'].fillna(data['color'].mode()[0], inplace=True)

# %%
data['director_name'].value_counts()
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Clint Eastwood      20
# Martin Scorsese     20
# Ridley Scott        17
#                     ..
# John Crowley         1
# Rob Pritts           1
# David S. Ward        1
# R.J. Cutler          1
# Daniel Hsia          1
# Name: director_name, Length: 2398, dtype: int64

# %%
data['director_name'].fillna('Unknown', inplace=True)

# %%
data['num_critic_for_reviews'].value_counts()
# Out:
# 1.0      43
# 9.0      37
# 5.0      36
# 10.0     35
# 8.0      35
#          ..
# 738.0     1
# 476.0     1
# 775.0     1
# 552.0     1
# 409.0     1
# Name: num_critic_for_reviews, Length: 528, dtype: int64

# %%
data['num_critic_for_reviews'].value_counts().sort_values()
# Out:
# 409.0     1
# 427.0     1
# 669.0     1
# 676.0     1
# 479.0     1
#          ..
# 8.0      35
# 10.0     35
# 5.0      36
# 9.0      37
# 1.0      43
# Name: num_critic_for_reviews, Length: 528, dtype: int64

# %%
print('mean_of',data['num_critic_for_reviews'].mean())
print('median_of',data['num_critic_for_reviews'].median())
print('mode_of',data['num_critic_for_reviews'].mode())
# Out:
# mean_of 140.1942719807731
# median_of 110.0
# mode_of 0    1.0
# Name: num_critic_for_reviews, dtype: float64

# %%
data['num_critic_for_reviews'].fillna(data['num_critic_for_reviews'].median(), inplace=True)

# %%
data['duration'].value_counts()
# Out:
# 90.0     161
# 100.0    141
# 101.0    139
# 98.0     135
# 97.0     131
#         ...
# 236.0      1
# 334.0      1
# 270.0      1
# 227.0      1
# 47.0       1
# Name: duration, Length: 191, dtype: int64

# %%
print('mean_of',data['duration'].mean())
print('median_of',data['duration'].median())
print('mode_of',data['duration'].mode())
# Out:
# mean_of 107.2010739856802
# median_of 103.0
# mode_of 0    90.0
# Name: duration, dtype: float64

# %%
data['duration'].fillna(data['duration'].median(), inplace=True)

# %%
data['director_facebook_likes'].value_counts()
# Out:
# 0.0      907
# 3.0       70
# 6.0       66
# 7.0       64
# 2.0       63
#         ...
# 593.0      1
# 434.0      1
# 482.0      1
# 667.0      1
# 291.0      1
# Name: director_facebook_likes, Length: 435, dtype: int64

# %%
print('mean_of',data['director_facebook_likes'].mean())
print('median_of',data['director_facebook_likes'].median())
print('mode_of',data['director_facebook_likes'].mode())
# Out:
# mean_of 686.5092123911724
# median_of 49.0
# mode_of 0    0.0
# Name: director_facebook_likes, dtype: float64

# %%
data['director_facebook_likes'].fillna(data['director_facebook_likes'].median(), inplace=True)

# %%
data.actor_3_facebook_likes.value_counts().sort_values
# Out:
# <bound method Series.sort_values of 1000.0     126
# 0.0         89
# 11000.0     29
# 3.0         28
# 2000.0      27
#           ...
# 867.0        1
# 974.0        1
# 369.0        1
# 607.0        1
# 156.0        1
# Name: actor_3_facebook_likes, Length: 906, dtype: int64>

# %%
print('mean_of',data['director_facebook_likes'].mean())
print('median_of',data['director_facebook_likes'].median())
print('mode_of',data['director_facebook_likes'].mode())
# Out:
# mean_of 673.362086059885
# median_of 49.0
# mode_of 0    0.0
# Name: director_facebook_likes, dtype: float64

# %%
data['director_facebook_likes'].fillna(data['director_facebook_likes'].median(), inplace=True)
data['actor_3_facebook_likes'].fillna(data['actor_3_facebook_likes'].median(), inplace=True)
data['actor_1_facebook_likes'].fillna(data['actor_1_facebook_likes'].median(), inplace=True)
data['actor_2_facebook_likes'].fillna(data['actor_2_facebook_likes'].median(), inplace=True)

# %%
data.actor_2_name.value_counts()
# Out:
# Morgan Freeman          20
# Charlize Theron         15
# Brad Pitt               14
# James Franco            11
# Meryl Streep            11
#                         ..
# Joaquim de Almeida       1
# Simón Andreu             1
# Nora von Waldstätten     1
# Mackenzie Gray           1
# Brian Herzlinger         1
# Name: actor_2_name, Length: 3032, dtype: int64

# %%
data['actor_2_name'].fillna('Unknown', inplace=True)
data['actor_1_name'].fillna('Unknown', inplace=True)
data['actor_3_name'].fillna('Unknown', inplace=True)

# %%
data.gross.value_counts()
# Out:
# 47000000.0     3
# 34964818.0     3
# 5773519.0      3
# 3000000.0      3
# 177343675.0    3
#               ..
# 39026186.0     1
# 33422806.0     1
# 33423521.0     1
# 32519322.0     1
# 85222.0        1
# Name: gross, Length: 4035, dtype: int64

# %%
print('mean_of',data['gross'].mean())
print('median_of',data['gross'].median())
print('mode_of',data['gross'].mode())
# Out:
# mean_of 48468407.52680933
# median_of 25517500.0
# mode_of 0      3000000.0
# 1      5773519.0
# 2      8000000.0
# 3     34964818.0
# 4     47000000.0
# 5    144512310.0
# 6    177343675.0
# 7    218051260.0
# Name: gross, dtype: float64

# %%
data['gross'].fillna(data['gross'].mean(), inplace=True)

# %%
data.facenumber_in_poster.value_counts()
# Out:
# 0.0     2152
# 1.0     1251
# 2.0      716
# 3.0      380
# 4.0      207
# 5.0      114
# 6.0       76
# 7.0       48
# 8.0       37
# 9.0       18
# 10.0      10
# 15.0       6
# 11.0       5
# 12.0       4
# 13.0       2
# 31.0       1
# 14.0       1
# 19.0       1
# 43.0       1
# Name: facenumber_in_poster, dtype: int64

# %%
print('mean_of',data['facenumber_in_poster'].mean())
print('median_of',data['facenumber_in_poster'].median())
print('mode_of',data['facenumber_in_poster'].mode())
# Out:
# mean_of 1.3711729622266402
# median_of 1.0
# mode_of 0    0.0
# Name: facenumber_in_poster, dtype: float64

# %%
data['facenumber_in_poster'].fillna(data['facenumber_in_poster'].mode()[0], inplace=True)

# %%
data.plot_keywords.value_counts()
# Out:
# based on novel                                                                        4
# eighteen wheeler|illegal street racing|truck|trucker|undercover cop                   3
# one word title                                                                        3
# assistant|experiment|frankenstein|medical student|scientist                           3
# animal name in title|ape abducts a woman|gorilla|island|king kong                     3
#                                                                                      ..
# dance|dance crew|dancer|mortgage|new york city                                        1
# africa|eyeglasses|money|texas|veteran                                                 1
# hit by a pickup truck|immortality|paramedic|resuscitation|san francisco california    1
# evil|fight|hell|psychic|psychologist                                                  1
# actress name in title|crush|date|four word title|video camera                         1
# ...

# %%
data.num_user_for_reviews.value_counts()
# Out:
# 1       51
# 3       33
# 2       32
# 26      32
# 10      29
#         ..
# 1344     1
# 1401     1
# 1206     1
# 856      1
# 586      1
# Name: num_user_for_reviews, Length: 955, dtype: int64

# %%
data
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4     Color        Doug Walker                   110.0     103.0
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color            Unknown                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
# Convert the 'num_user_for_reviews' column to numeric, ignoring errors
data['num_user_for_reviews'] = pd.to_numeric(data['num_user_for_reviews'], errors='coerce')

# Now calculate mean, median, mode
print('mean_of', data['num_user_for_reviews'].mean())
print('median_of', data['num_user_for_reviews'].median())
print('mode_of', data['num_user_for_reviews'].mode())
# Out:
# mean_of 272.77080844285143
# median_of 156.0
# mode_of 0    1.0
# Name: num_user_for_reviews, dtype: float64

# %%
data['num_user_for_reviews'].fillna(data['num_user_for_reviews'].median(), inplace=True)

# %%
data.isnull().sum()
# Out:
# color                          0
# director_name                  0
# num_critic_for_reviews         0
# duration                       0
# director_facebook_likes        0
# actor_3_facebook_likes         0
# actor_2_name                   0
# actor_1_facebook_likes         0
# gross                          0
# genres                         0
# actor_1_name                   0
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                   0
# facenumber_in_poster           0
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews           0
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes         0
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
data.language.value_counts()
# Out:
# English       4704
# French          73
# Spanish         40
# Hindi           28
# Mandarin        26
# German          19
# Japanese        18
# Cantonese       11
# Russian         11
# Italian         11
# Portuguese       8
# Korean           8
# Arabic           5
# Danish           5
# Hebrew           5
# Swedish          5
# Polish           4
# Norwegian        4
# Persian          4
# Dutch            4
# Thai             3
# Chinese          3
# Icelandic        2
# None             2
# Indonesian       2
# Aboriginal       2
# Romanian         2
# Dari             2
# Zulu             2
# Panjabi          1
# Urdu             1
# Vietnamese       1
# Slovenian        1
# Greek            1
# Dzongkha         1
# Tamil            1
# Telugu           1
# Kannada          1
# Czech            1
# Hungarian        1
# Bosnian          1
# Filipino         1
# Mongolian        1
# Maya             1
# Aramaic          1
# Kazakh           1
# Swahili          1
# ...

# %%
data['language'].fillna(data['language'].mode()[0], inplace = True)

# %%
data.content_rating.value_counts()
# Out:
# R            2118
# PG-13        1461
# PG            701
# Not Rated     116
# G             112
# Unrated        62
# Approved       55
# TV-14          30
# TV-MA          20
# TV-PG          13
# X              13
# TV-G           10
# Passed          9
# NC-17           7
# GP              6
# M               5
# TV-Y            1
# TV-Y7           1
# Name: content_rating, dtype: int64

# %%
data['content_rating'].fillna(data['content_rating'].mode()[0], inplace = True)

# %%
data.isnull().sum()
# Out:
# color                          0
# director_name                  0
# num_critic_for_reviews         0
# duration                       0
# director_facebook_likes        0
# actor_3_facebook_likes         0
# actor_2_name                   0
# actor_1_facebook_likes         0
# gross                          0
# genres                         0
# actor_1_name                   0
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                   0
# facenumber_in_poster           0
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews           0
# language                       0
# country                        5
# content_rating                 0
# budget                       492
# title_year                   108
# actor_2_facebook_likes         0
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
data.budget.value_counts()
# Out:
# 20000000.0    174
# 15000000.0    143
# 25000000.0    142
# 30000000.0    141
# 10000000.0    135
#              ...
# 10818775.0      1
# 13800000.0      1
# 12305523.0      1
# 12600000.0      1
# 1100.0          1
# Name: budget, Length: 439, dtype: int64

# %%
print('mean_of',data['budget'].mean())
print('median_of',data['budget'].median())
print('mode_of',data['budget'].mode())
# Out:
# mean_of 39752620.436387606
# median_of 20000000.0
# mode_of 0    20000000.0
# Name: budget, dtype: float64

# %%
data.budget.fillna(data['budget'].median(), inplace = True)

# %%
data.title_year.value_counts()
# Out:
# 2009.0    260
# 2014.0    252
# 2006.0    239
# 2013.0    237
# 2010.0    230
#          ...
# 1932.0      1
# 1916.0      1
# 1934.0      1
# 1925.0      1
# 1920.0      1
# Name: title_year, Length: 91, dtype: int64

# %%
print('mean_of',data['title_year'].mean())
print('median_of',data['title_year'].median())
print('mode_of',data['title_year'].mode())
# Out:
# mean_of 2002.4705167173252
# median_of 2005.0
# mode_of 0    2009.0
# Name: title_year, dtype: float64

# %%
data.title_year.fillna('unknown', inplace = True)

# %%
data.isnull().sum()
# Out:
# color                          0
# director_name                  0
# num_critic_for_reviews         0
# duration                       0
# director_facebook_likes        0
# actor_3_facebook_likes         0
# actor_2_name                   0
# actor_1_facebook_likes         0
# gross                          0
# genres                         0
# actor_1_name                   0
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                   0
# facenumber_in_poster           0
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews           0
# language                       0
# country                        5
# content_rating                 0
# budget                         0
# title_year                     0
# actor_2_facebook_likes         0
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
data.aspect_ratio.value_counts()
# Out:
# 2.35     2360
# 1.85     1906
# 1.78      110
# 1.37      100
# 1.33       68
# 1.66       64
# 16.00      45
# 2.39       15
# 2.20       15
# 4.00        7
# 2.00        5
# 2.40        3
# 2.76        3
# 1.75        3
# 1.50        2
# 2.55        2
# 2.24        1
# 1.77        1
# 1.18        1
# 1.44        1
# 1.20        1
# 1.89        1
# Name: aspect_ratio, dtype: int64

# %%
print('mean_of',data['aspect_ratio'].mean())
print('median_of',data['aspect_ratio'].median())
print('mode_of',data['aspect_ratio'].mode())
# Out:
# mean_of 2.22040305473059
# median_of 2.35
# mode_of 0    2.35
# Name: aspect_ratio, dtype: float64

# %%
data['aspect_ratio'].fillna(data['aspect_ratio'].median(), inplace = True)

# %%
data.plot_keywords.fillna(data['plot_keywords'].mode()[0], inplace = True)

# %%
data.country.value_counts()
# Out:
# USA              3807
# UK                448
# France            154
# Canada            126
# Germany            97
#                  ...
# Slovakia            1
# Chile               1
# Cambodia            1
# Official site       1
# Philippines         1
# Name: country, Length: 65, dtype: int64

# %%
data.country.fillna(data['country'].mode()[0], inplace = True)

# %%
data.isnull().sum()
# Out:
# color                        0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# movie_imdb_link              0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %%
data.genres.value_counts()
# Out:
# Drama                                         236
# Comedy                                        209
# Comedy|Drama                                  191
# Comedy|Drama|Romance                          187
# Comedy|Romance                                158
#                                              ...
# Crime|Drama|Mystery|Sci-Fi|Thriller             1
# Adventure|Comedy|Crime|Drama                    1
# Action|Crime|Drama|Mystery|Sci-Fi|Thriller      1
# Action|Drama|Fantasy|Horror|Thriller            1
# Comedy|Crime|Horror                             1
# Name: genres, Length: 914, dtype: int64

# %%
data['genres'] = data['genres'].str.split('|', expand=False).apply(lambda x: x[0] if x is not None else None)

# %%
data.genres.value_counts()
# Out:
# Comedy         1329
# Action         1153
# Drama           972
# Adventure       453
# Crime           349
# Biography       252
# Horror          232
# Documentary      84
# Animation        61
# Fantasy          53
# Mystery          33
# Thriller         22
# Sci-Fi           13
# Western          12
# Family           11
# Romance           6
# Musical           4
# Game-Show         1
# Music             1
# Film-Noir         1
# History           1
# Name: genres, dtype: int64

# %%
data['movie_title'] = data['movie_title'].str.split(':').apply(lambda x: x[0].strip() if x is not None else None)

# %%
data['movie_title']
# Out:
# 0                         Avatar
# 1       Pirates of the Caribbean
# 2                        Spectre
# 3          The Dark Knight Rises
# 4                      Star Wars
#                   ...
# 5038     Signed Sealed Delivered
# 5039               The Following
# 5040        A Plague So Pleasant
# 5041            Shanghai Calling
# 5042           My Date with Drew
# Name: movie_title, Length: 5043, dtype: object

# %%
data['plot_keywords'] = data['plot_keywords'].str.split('|').apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None)

# %%
data.plot_keywords.value_counts()
# Out:
# based on novel           172
# alien                     79
# death                     50
# boy                       41
# best friend               39
#                         ...
# makeover                   1
# kid                        1
# abdication                 1
# arrogance                  1
# actress name in title      1
# Name: plot_keywords, Length: 2063, dtype: int64

# %%
data
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4     Color        Doug Walker                   110.0     103.0
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color            Unknown                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
data.drop(columns=['movie_imdb_link'], inplace=True)

# %%
data.shape
# Out:
# (5043, 27)

# %%
data
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4     Color        Doug Walker                   110.0     103.0
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color            Unknown                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
data.isnull().sum()
# Out:
# color                        0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %%
data.to_csv('imbd_Data.csv', index=False)
